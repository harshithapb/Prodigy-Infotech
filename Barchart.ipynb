# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithapb/Prodigy-Infotech/blob/main/Barchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r'/content/sample_data/Bar chart/BELGIUM_POPULATION_STRUCTURE_2018.csv',encoding='latin-1')
dataset.head()
# Out:
#    MUNICIPALITY REFNIS CODE MUNICIPALITY NAME  DISTRICT REFNIS CODE  \
# 0                     71024      Herk-de-Stad                 71000
# 1                     71037            Lummen                 71000
# 2                     71011        Diepenbeek                 71000
# 3                     71016              Genk                 71000
# 4                     71017          Gingelom                 71000
#
#   DISTRICT NAME  PROVINCE REFNIS CODE PROVINCE NAME  REGION REFNIS CODE  \
# 0       Hasselt                 70000       Limburg                2000
# 1       Hasselt                 70000       Limburg                2000
# 2       Hasselt                 70000       Limburg                2000
# 3       Hasselt                 70000       Limburg                2000
# 4       Hasselt                 70000       Limburg                2000
#
#       REGION NAME GENDER NATIONALITY CIVIL CODE STATUS   AGE  POPULATION
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33104 entries, 0 to 33103
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MUNICIPALITY REFNIS CODE  33104 non-null  int64
#  1   MUNICIPALITY NAME         33104 non-null  object
#  2   DISTRICT REFNIS CODE      33104 non-null  int64
#  3   DISTRICT NAME             33104 non-null  object
#  4   PROVINCE REFNIS CODE      33104 non-null  int64
#  5   PROVINCE NAME             33104 non-null  object
#  6   REGION REFNIS CODE        33104 non-null  int64
#  7   REGION NAME               33104 non-null  object
#  8   GENDER                    33103 non-null  object
#  9   NATIONALITY               33103 non-null  object
#  10  CIVIL CODE STATUS         33103 non-null  object
#  11  AGE                       33103 non-null  float64
#  12  POPULATION                33103 non-null  float64
# dtypes: float64(2), int64(4), object(7)
# ...

# %%
dataset.isna()
# Out:
#        MUNICIPALITY REFNIS CODE  MUNICIPALITY NAME  DISTRICT REFNIS CODE  \
# 0                         False              False                 False
# 1                         False              False                 False
# 2                         False              False                 False
# 3                         False              False                 False
# 4                         False              False                 False
# ...                         ...                ...                   ...
# 33099                     False              False                 False
# 33100                     False              False                 False
# 33101                     False              False                 False
# 33102                     False              False                 False
# 33103                     False              False                 False
#
#        DISTRICT NAME  PROVINCE REFNIS CODE  PROVINCE NAME  REGION REFNIS CODE  \
# ...

# %%
dataset = pd.DataFrame(dataset)
plt.figure(figsize=(10, 6))
plt.hist(dataset['AGE'], bins=10, color='gold', edgecolor='black')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age Variable')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %%
dataset = pd.DataFrame(dataset)
plt.figure(figsize=(6, 4))
gender_counts = dataset['GENDER'].value_counts()
bar_width = 0.5
plt.bar(gender_counts.index, gender_counts, width=bar_width, color=['lightgreen', 'mediumpurple'], edgecolor='black')

plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Gender Variable')
plt.grid(axis='y', alpha=0.5)

plt.show()
